# %% [markdown]
# <a href="https://colab.research.google.com/github/MMoltira/KKU_data_mining/blob/master/Data102.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
import pandas as pd
base_path = '/content/drive/My Drive/DWDM_material'
data = pd.read_csv(os.path.join(base_path,'test.csv'))
data.head()
# Out:
#    Unnamed: 0        x        y
# 0           0  55.3846  97.1795
# 1           1  51.5385  96.0256
# 2           2  46.1538  94.4872
# 3           3  42.8205  91.4103
# 4           4  40.7692  88.3333

# %%
data.describe()
# Out:
#        Unnamed: 0           x           y
# count  142.000000  142.000000  142.000000
# mean    70.500000   54.263273   47.832253
# std     41.135953   16.765142   26.935403
# min      0.000000   22.307700    2.948700
# 25%     35.250000   44.102600   25.288450
# 50%     70.500000   53.333300   46.025600
# 75%    105.750000   64.743600   68.525675
# max    141.000000   98.205100   99.487200

# %%
from matplotlib import pyplot as plt

# %%
plt.boxplot(data['x'])
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f671c0d0710>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f671c064160>,
#   <matplotlib.lines.Line2D at 0x7f671c0644e0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f671c064be0>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7f671c064860>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f671c0d0a20>,
#   <matplotlib.lines.Line2D at 0x7f671c0d0da0>]}

# %%
plt.boxplot(data['x'],vert=False)
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f671bba2cf8>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f671bbaf748>,
#   <matplotlib.lines.Line2D at 0x7f671bbafac8>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f671bbba208>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7f671bbafe48>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f671bbaf048>,
#   <matplotlib.lines.Line2D at 0x7f671bbaf3c8>]}

# %%
plt.boxplot(data['x'],vert = False, whis=1.2 )
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f671c03d198>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f671c054128>,
#   <matplotlib.lines.Line2D at 0x7f671c0546d8>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f671bb52588>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7f671bb52828>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f671c03de10>,
#   <matplotlib.lines.Line2D at 0x7f671bbc8278>]}

# %%
oput = plt.boxplot(data['x'],vert = False, whis=1.2 )

# %%
oput['fliers'][0].get_xdata()
# Out:
# array([93.3333, 95.3846, 98.2051, 91.2821])

# %%
oput['whiskers'][0].get_xdata()
# Out:
# array([44.1026, 22.3077])

# %%
oput['whiskers'][1].get_xdata()
# Out:
# array([64.7436, 89.4872])

# %%
plt.scatter(data['x'],data['y'])

# %%
plt.scatter(data['x'],data['y'],s=data['y'],c='r')

# %%
plt.scatter(data['x'],data['y'],s=data['y'],c='c')

# %%
plt.scatter(data['x'],data['y'],s=data['y'],c='m')

# %%
plt.scatter(data['x'],data['y'],s=data['y'],c='k')

# %%
plt.scatter(data['x'],data['y'],s=data['y'],c='k',marker='p')

# %%
plt.scatter(data['x'],data['y'],s=data['y'],c='r',marker='p',alpha=0.4)
plt.scatter([44,42,50],[15,14,80], s=250,alpha=0.6)

# %% [markdown]
# ##HW4 การบ้านให้เพิ่มปีกกับนอของไดโนเสาร์

# %%
plt.scatter(data['x'],data['y'],s=data['y'],c='m',marker='^')
plt.scatter([31,29,26,24,22,40,38,36,34,32,29,27,25,22,73,75,77,79,80,81,82,82,83,83,84,84,85,85,86,87,88,89,91,93,95,97,97,97,97,97,97,97,97,96,95,95,94,93,92,91,90,89],[80,83,85,87,89,89,89,89,89,89,89,89,89,89,35,36,40,44,47,50,53,57,60,63,65,67,69,71,73,75,77,79,81,83,85,87,85,81,77,73,69,65,61,57,53,50,46,42,39,36,33,30],s=200,alpha=0.6)
plt.scatter([50],[80],s=250,alpha=0.6,c='k')

# %% [markdown]
# ##24/08/2020

# %% [markdown]
# ##plot

# %%
plt.plot(data['x'],data['y'],'ro-')

# %%
plt.plot(data['x'],data['y'],'ro-')
plt.plot(data['x'][0],data['y'][0],'k*')

# %%
plt.plot(data['x'],data['y'],'ro-')
plt.scatter(data['x'][0],data['y'][0],s=200,c='k')

# %%
plt.plot(data['x'],data['y'],'r-')
plt.scatter(data['x'],data['y'],s=range(10,len(data['x'])+10))

# %%
plt.scatter(data['x'],data['y'],s=250,c=[[0.1,0.1,0.9,0.2]])

# %%
color_list=[]
for i in range(len(data['x'])):
    color_list.append([0.1,0.1,i/255,0.2])
color_list
# Out:
# [[0.1, 0.1, 0.0, 0.2],
#  [0.1, 0.1, 0.00392156862745098, 0.2],
#  [0.1, 0.1, 0.00784313725490196, 0.2],
#  [0.1, 0.1, 0.011764705882352941, 0.2],
#  [0.1, 0.1, 0.01568627450980392, 0.2],
#  [0.1, 0.1, 0.0196078431372549, 0.2],
#  [0.1, 0.1, 0.023529411764705882, 0.2],
#  [0.1, 0.1, 0.027450980392156862, 0.2],
#  [0.1, 0.1, 0.03137254901960784, 0.2],
#  [0.1, 0.1, 0.03529411764705882, 0.2],
#  [0.1, 0.1, 0.0392156862745098, 0.2],
#  [0.1, 0.1, 0.043137254901960784, 0.2],
#  [0.1, 0.1, 0.047058823529411764, 0.2],
#  [0.1, 0.1, 0.050980392156862744, 0.2],
#  [0.1, 0.1, 0.054901960784313725, 0.2],
#  [0.1, 0.1, 0.058823529411764705, 0.2],
#  [0.1, 0.1, 0.06274509803921569, 0.2],
#  [0.1, 0.1, 0.06666666666666667, 0.2],
#  [0.1, 0.1, 0.07058823529411765, 0.2],
#  [0.1, 0.1, 0.07450980392156863, 0.2],
#  [0.1, 0.1, 0.0784313725490196, 0.2],
#  [0.1, 0.1, 0.08235294117647059, 0.2],
#  [0.1, 0.1, 0.08627450980392157, 0.2],
#  [0.1, 0.1, 0.09019607843137255, 0.2],
#  [0.1, 0.1, 0.09411764705882353, 0.2],
#  [0.1, 0.1, 0.09803921568627451, 0.2],
#  [0.1, 0.1, 0.10196078431372549, 0.2],
#  [0.1, 0.1, 0.10588235294117647, 0.2],
#  [0.1, 0.1, 0.10980392156862745, 0.2],
#  [0.1, 0.1, 0.11372549019607843, 0.2],
#  [0.1, 0.1, 0.11764705882352941, 0.2],
#  [0.1, 0.1, 0.12156862745098039, 0.2],
#  [0.1, 0.1, 0.12549019607843137, 0.2],
#  [0.1, 0.1, 0.12941176470588237, 0.2],
#  [0.1, 0.1, 0.13333333333333333, 0.2],
#  [0.1, 0.1, 0.13725490196078433, 0.2],
#  [0.1, 0.1, 0.1411764705882353, 0.2],
#  [0.1, 0.1, 0.1450980392156863, 0.2],
#  [0.1, 0.1, 0.14901960784313725, 0.2],
#  [0.1, 0.1, 0.15294117647058825, 0.2],
#  [0.1, 0.1, 0.1568627450980392, 0.2],
#  [0.1, 0.1, 0.1607843137254902, 0.2],
#  [0.1, 0.1, 0.16470588235294117, 0.2],
#  [0.1, 0.1, 0.16862745098039217, 0.2],
#  [0.1, 0.1, 0.17254901960784313, 0.2],
#  [0.1, 0.1, 0.17647058823529413, 0.2],
#  [0.1, 0.1, 0.1803921568627451, 0.2],
#  [0.1, 0.1, 0.1843137254901961, 0.2],
#  [0.1, 0.1, 0.18823529411764706, 0.2],
#  [0.1, 0.1, 0.19215686274509805, 0.2],
#  [0.1, 0.1, 0.19607843137254902, 0.2],
#  [0.1, 0.1, 0.2, 0.2],
#  [0.1, 0.1, 0.20392156862745098, 0.2],
#  [0.1, 0.1, 0.20784313725490197, 0.2],
#  [0.1, 0.1, 0.21176470588235294, 0.2],
#  [0.1, 0.1, 0.21568627450980393, 0.2],
#  [0.1, 0.1, 0.2196078431372549, 0.2],
#  [0.1, 0.1, 0.2235294117647059, 0.2],
#  [0.1, 0.1, 0.22745098039215686, 0.2],
#  [0.1, 0.1, 0.23137254901960785, 0.2],
#  [0.1, 0.1, 0.23529411764705882, 0.2],
#  [0.1, 0.1, 0.23921568627450981, 0.2],
#  [0.1, 0.1, 0.24313725490196078, 0.2],
#  [0.1, 0.1, 0.24705882352941178, 0.2],
#  [0.1, 0.1, 0.25098039215686274, 0.2],
#  [0.1, 0.1, 0.2549019607843137, 0.2],
#  [0.1, 0.1, 0.25882352941176473, 0.2],
#  [0.1, 0.1, 0.2627450980392157, 0.2],
#  [0.1, 0.1, 0.26666666666666666, 0.2],
#  [0.1, 0.1, 0.27058823529411763, 0.2],
#  [0.1, 0.1, 0.27450980392156865, 0.2],
#  [0.1, 0.1, 0.2784313725490196, 0.2],
#  [0.1, 0.1, 0.2823529411764706, 0.2],
#  [0.1, 0.1, 0.28627450980392155, 0.2],
#  [0.1, 0.1, 0.2901960784313726, 0.2],
#  [0.1, 0.1, 0.29411764705882354, 0.2],
#  [0.1, 0.1, 0.2980392156862745, 0.2],
#  [0.1, 0.1, 0.30196078431372547, 0.2],
#  [0.1, 0.1, 0.3058823529411765, 0.2],
#  [0.1, 0.1, 0.30980392156862746, 0.2],
#  [0.1, 0.1, 0.3137254901960784, 0.2],
#  [0.1, 0.1, 0.3176470588235294, 0.2],
#  [0.1, 0.1, 0.3215686274509804, 0.2],
#  [0.1, 0.1, 0.3254901960784314, 0.2],
#  [0.1, 0.1, 0.32941176470588235, 0.2],
#  [0.1, 0.1, 0.3333333333333333, 0.2],
#  [0.1, 0.1, 0.33725490196078434, 0.2],
#  [0.1, 0.1, 0.3411764705882353, 0.2],
#  [0.1, 0.1, 0.34509803921568627, 0.2],
#  [0.1, 0.1, 0.34901960784313724, 0.2],
#  [0.1, 0.1, 0.35294117647058826, 0.2],
#  [0.1, 0.1, 0.3568627450980392, 0.2],
#  [0.1, 0.1, 0.3607843137254902, 0.2],
#  [0.1, 0.1, 0.36470588235294116, 0.2],
#  [0.1, 0.1, 0.3686274509803922, 0.2],
#  [0.1, 0.1, 0.37254901960784315, 0.2],
#  [0.1, 0.1, 0.3764705882352941, 0.2],
#  [0.1, 0.1, 0.3803921568627451, 0.2],
#  [0.1, 0.1, 0.3843137254901961, 0.2],
#  [0.1, 0.1, 0.38823529411764707, 0.2],
#  [0.1, 0.1, 0.39215686274509803, 0.2],
#  [0.1, 0.1, 0.396078431372549, 0.2],
#  [0.1, 0.1, 0.4, 0.2],
#  [0.1, 0.1, 0.403921568627451, 0.2],
#  [0.1, 0.1, 0.40784313725490196, 0.2],
#  [0.1, 0.1, 0.4117647058823529, 0.2],
#  [0.1, 0.1, 0.41568627450980394, 0.2],
#  [0.1, 0.1, 0.4196078431372549, 0.2],
#  [0.1, 0.1, 0.4235294117647059, 0.2],
#  [0.1, 0.1, 0.42745098039215684, 0.2],
#  [0.1, 0.1, 0.43137254901960786, 0.2],
#  [0.1, 0.1, 0.43529411764705883, 0.2],
#  [0.1, 0.1, 0.4392156862745098, 0.2],
#  [0.1, 0.1, 0.44313725490196076, 0.2],
#  [0.1, 0.1, 0.4470588235294118, 0.2],
#  [0.1, 0.1, 0.45098039215686275, 0.2],
#  [0.1, 0.1, 0.4549019607843137, 0.2],
#  [0.1, 0.1, 0.4588235294117647, 0.2],
#  [0.1, 0.1, 0.4627450980392157, 0.2],
#  [0.1, 0.1, 0.4666666666666667, 0.2],
#  [0.1, 0.1, 0.47058823529411764, 0.2],
#  [0.1, 0.1, 0.4745098039215686, 0.2],
#  [0.1, 0.1, 0.47843137254901963, 0.2],
#  [0.1, 0.1, 0.4823529411764706, 0.2],
#  [0.1, 0.1, 0.48627450980392156, 0.2],
#  [0.1, 0.1, 0.49019607843137253, 0.2],
#  [0.1, 0.1, 0.49411764705882355, 0.2],
#  [0.1, 0.1, 0.4980392156862745, 0.2],
#  [0.1, 0.1, 0.5019607843137255, 0.2],
#  [0.1, 0.1, 0.5058823529411764, 0.2],
#  [0.1, 0.1, 0.5098039215686274, 0.2],
#  [0.1, 0.1, 0.5137254901960784, 0.2],
#  [0.1, 0.1, 0.5176470588235295, 0.2],
#  [0.1, 0.1, 0.5215686274509804, 0.2],
#  [0.1, 0.1, 0.5254901960784314, 0.2],
#  [0.1, 0.1, 0.5294117647058824, 0.2],
#  [0.1, 0.1, 0.5333333333333333, 0.2],
#  [0.1, 0.1, 0.5372549019607843, 0.2],
#  [0.1, 0.1, 0.5411764705882353, 0.2],
#  [0.1, 0.1, 0.5450980392156862, 0.2],
#  [0.1, 0.1, 0.5490196078431373, 0.2],
#  [0.1, 0.1, 0.5529411764705883, 0.2]]

# %%
plt.scatter(data['x'],data['y'],s=250,c=color_list)

# %% [markdown]
# ## Barchart

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

# %%
labels = ['G1', 'G2', 'G3', 'G4', 'G5']
men_means = [20, 34, 30, 35, 27]
women_means = [25, 32, 34, 20, 25]

# %%
x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

# %%
plt.bar(x - width/2, men_means, width, label='Men')
plt.bar(x + width/2, women_means, width, label='Women')
# Out:
# <BarContainer object of 5 artists>

# %%
fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, men_means, width, label='Men')
rects2 = ax.bar(x + width/2, women_means, width, label='Women')

# %%
fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, men_means, width, label='Men')
rects2 = ax.bar(x + width/2, women_means, width, label='Women')

ax.set_ylabel('Scores')
# Out:
# Text(0, 0.5, 'Scores')

# %%
fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, men_means, width, label='Men')
rects2 = ax.bar(x + width/2, women_means, width, label='Women')

ax.set_ylabel('Scores')
ax.set_title('Scores by group and gender')
# Out:
# Text(0.5, 1.0, 'Scores by group and gender')

# %%
fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, men_means, width, label='Men')
rects2 = ax.bar(x + width/2, women_means, width, label='Women')

ax.set_ylabel('Scores')
ax.set_title('Scores by group and gender')
ax.set_xticks(x)
ax.set_xticklabels(labels);

# %%
fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, men_means, width, label='Men')
rects2 = ax.bar(x + width/2, women_means, width, label='Women')

ax.set_ylabel('Scores')
ax.set_title('Scores by group and gender')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend();

# %%
plt.bar(x - width/2, men_means, width, label='Men')
plt.bar(x + width/2, women_means, width, label='Women')
plt.ylabel('Scores')
plt.title('Scores by group and gender')
plt.legend();

# %% [markdown]
# ## Histogram

# %%
x=[12,25,7,7,1,1,1,1,5,5,5,5]

# %%
plt.hist(x)
# Out:
# (array([4., 4., 2., 0., 1., 0., 0., 0., 0., 1.]),
#  array([ 1. ,  3.4,  5.8,  8.2, 10.6, 13. , 15.4, 17.8, 20.2, 22.6, 25. ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist('a a a s d f a s d f s a d f e w r w e f s d f'.split())
# Out:
# (array([5., 4., 0., 4., 0., 5., 2., 0., 2., 1.]),
#  array([0. , 0.6, 1.2, 1.8, 2.4, 3. , 3.6, 4.2, 4.8, 5.4, 6. ]),
#  <a list of 10 Patch objects>)
