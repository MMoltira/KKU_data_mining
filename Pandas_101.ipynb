# %% [markdown]
# <a href="https://colab.research.google.com/github/MMoltira/KKU_data_mining/blob/master/Pandas_101.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas

# %%
from google.colab import drive #เชื่อม Drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path='/content/drive/My Drive/DWDM_material'

# %%
import os
import pandas # เรียกใช้ฟังก์ชัน

# %%
search_click = os.path.join(path,'search_click.csv') #สร้างที่อยู่โดยใช้ os.path.join
w_restaurant = os.path.join(path,'w_restaurant.csv')

# %% [markdown]
# #Then use pandas to load the data into the environment

# %%
search_click_df = pandas.read_csv(search_click)

# %%
search_click_df.head()
# Out:
#   click_timestamp                             search_id  ...  time_diff_nanos   ads
# 0         11:38.9  5c004472-5ecc-4159-9698-9f329b8e26e1  ...     2.222400e+15  True
# 1         30:51.3  5f34eca0-c04e-4c10-b600-54aa447dbd8e  ...     4.608380e+14  True
# 2         32:09.6  8dc6d1f0-11f1-4239-9dd2-5c1674c81224  ...     2.581490e+15  True
# 3         00:59.8  1a5810e9-3d1f-44b9-9a2e-26ede21c524b  ...     1.404580e+15  True
# 4         23:36.8  6bc75e0d-fc65-471e-9926-ff6be6708639  ...     9.333590e+14  True
#
# [5 rows x 6 columns]

# %%
w_restaurant_df = pandas.read_csv(w_restaurant)

# %%
w_restaurant_df.head()
# Out:
#    id              name  domain_id  ...  hotel_restaurant pet_friendly delivery
# 0   2  นครินทร์ทันตกรรม          2  ...               NaN          NaN      NaN
# 1   4      Corner House          1  ...               NaN          NaN      NaN
# 2   5    วัดโลกยสุธาราม          4  ...               NaN          NaN      NaN
# 3   6    นันท์คาราโอเกะ          1  ...               NaN          NaN      NaN
# 4   7       Buono Caffe          1  ...               NaN          NaN      NaN
#
# [5 rows x 32 columns]

# %% [markdown]
# #To check if the dimension of loaded data is correct as described in the description

# %%
search_click_df.shape # .shape เป็นคำสั่งที่ใช้เช็คว่าข้อมูลที่เอามามีความผิดพลาดรึเปล่า จำนวนแถว,จำนวนหลัก
# Out:
# (1048575, 6)

# %%
w_restaurant_df.shape
# Out:
# (246847, 32)

# %% [markdown]
# 0. Point to data in the table การชี้ข้อมูลไปที่ตารางโดยใช้ Dict

# %%
search_click_df['search_id'] #ใช้ชื่อคอลัมเรียกออกมา คือ search_id
# Out:
# 0          5c004472-5ecc-4159-9698-9f329b8e26e1
# 1          5f34eca0-c04e-4c10-b600-54aa447dbd8e
# 2          8dc6d1f0-11f1-4239-9dd2-5c1674c81224
# 3          1a5810e9-3d1f-44b9-9a2e-26ede21c524b
# 4          6bc75e0d-fc65-471e-9926-ff6be6708639
#                            ...
# 1048570    99aab616-6fc5-4fbf-994b-4aebee7bb360
# 1048571    d70a2c5d-ee94-4e4c-9f7c-c5faac6db12a
# 1048572    4c1de7fe-300e-41aa-9d01-914344fc3753
# 1048573    2ec0ddec-e450-4b98-9779-42b77aa7eda5
# 1048574    5741d9cf-b9f1-441d-aa83-d2b0179bf874
# Name: search_id, Length: 1048575, dtype: object

# %%
search_click_df['search_id'][0] #indexแรก คือ คอมลัม indexสอง คือ แถวหรือลำดับของข้อมูล
# Out:
# '5c004472-5ecc-4159-9698-9f329b8e26e1'

# %% [markdown]
# #iloc เปลี่ยนมุมมองตารางให้เป็นเหมือน numply คือ มีคอลัมและแถว

# %%
search_click_df.iloc[0,1]
# Out:
# '5c004472-5ecc-4159-9698-9f329b8e26e1'

# %%
search_click_df.iloc[:10,:2] # เรียกดูข้อมูล แถวที่ 0-9 ของคอลัมที่ 0-1
# Out:
#   click_timestamp                             search_id
# 0         11:38.9  5c004472-5ecc-4159-9698-9f329b8e26e1
# 1         30:51.3  5f34eca0-c04e-4c10-b600-54aa447dbd8e
# 2         32:09.6  8dc6d1f0-11f1-4239-9dd2-5c1674c81224
# 3         00:59.8  1a5810e9-3d1f-44b9-9a2e-26ede21c524b
# 4         23:36.8  6bc75e0d-fc65-471e-9926-ff6be6708639
# 5         48:16.7  92ea02ba-2c89-4efd-973c-e23526c531de
# 6         39:18.4  79d61918-fb3e-4181-99b6-7a7abddfcdb1
# 7         33:39.0  7f8b2b57-dea1-4fe1-84c8-5a7d63750e47
# 8         07:48.3  3d9217bb-3eae-42b5-8cf3-a756efae2cfa
# 9         41:25.4  a2cb0d41-6e1f-4169-9140-cb671fbb41dc

# %%
w_restaurant_df[['name','city_name','weighted_average_rating']] #อยากได้แค่บางส่วนโดยการตัดตารางด้วยชื่อคอลัมที่มีอยู่ อยากได้ name , city_name , weighted_average_rating 
#โดยจะมีเครื่องหมายลิสต์ 2 อันซ้อนกันอยู่ [[]]
# Out:
#                                         name  ... weighted_average_rating
# 0                           นครินทร์ทันตกรรม  ...                5.000000
# 1                               Corner House  ...                2.000000
# 2                             วัดโลกยสุธาราม  ...                4.000000
# 3                             นันท์คาราโอเกะ  ...                0.000000
# 4                                Buono Caffe  ...                3.738462
# ...                                      ...  ...                     ...
# 246842                            Sushi Tama  ...                3.663522
# 246843                     สะบายดี คาราโอเกะ  ...                0.000000
# 246844                      สเต็กแม่&กาแฟลูก  ...                4.000000
# 246845                              Mom Made  ...                5.000000
# 246846  ก๋วยเตี๋ยวหมูน้ำตก ก๋วยเตี๋ยวเรือทอง  ...                3.000000
#
# [246847 rows x 3 columns]

# %% [markdown]
# #Missing Values
# .isnull : ดูค่า missing ในตาราง

# %%
#เช็คว่าตารางมี missing หรือไม่
## Missing Values
search_click_df.isnull() #แต่ละช่องในตารางเป็นช่องว่างหรือป่าว
# Out:
#          click_timestamp  search_id  ...  time_diff_nanos    ads
# 0                  False      False  ...            False  False
# 1                  False      False  ...            False  False
# 2                  False      False  ...            False  False
# 3                  False      False  ...            False  False
# 4                  False      False  ...            False  False
# ...                  ...        ...  ...              ...    ...
# 1048570            False      False  ...            False  False
# 1048571            False      False  ...            False  False
# 1048572            False      False  ...            False  False
# 1048573            False      False  ...            False  False
# 1048574            False      False  ...            False  False
#
# [1048575 rows x 6 columns]

# %%
search_click_df.isnull().any() #.any จะยุบรวม T ในแต่ละคอลัมมา or กัน ดูตามแนวคอลัมว่ามี missing หรือไม่
# Out:
# click_timestamp     False
# search_id            True
# business_id          True
# display_position    False
# time_diff_nanos     False
# ads                 False
# dtype: bool

# %%
search_click_df.isnull().any().any()
# Out:
# True

# %% [markdown]
# #Handling missing values 1 การจัดการ Missing
# data ไหนมี missing อยู่ก็ให้ลบออก

# %%
search_click_df_nm=search_click_df.dropna() # .dropna() คือ การลบ missing ออกจากตาราง search_click_df แล้วสร้างตัวแปรใหม่มารับ

# %%
search_click_df_nm.isnull().any().any() #เอามาเช็คอีกรอบจะเห็นว่าเป็น False แล้ว คือ ไม่มี missing อยู่ แต่จะทำให้ข้อมูลมันลดลง
# Out:
# False

# %%
print(search_click_df.shape)
print(search_click_df_nm.shape)
# Out:
# (1048575, 6)
# (1048206, 6)

# %% [markdown]
# ##Excercise 1 ตรวจสอบว่า การลบข้อมูล missing ออกจากตาราง w_restaurant จะทำให้ข้อมูลลดลงกี่%

# %%
size_before_drop = w_restaurant_df.shape[0]
size_after_drop = w_restaurant_df.dropna().shape[0]
print(f'size before drop = {size_before_drop} size after drop = {size_after_drop}')
# Out:
# size before drop = 246847 size after drop = 4

# %%
size_before_drop = w_restaurant_df.shape[0]
size_after_drop = w_restaurant_df.dropna().shape[0]
print(f'size before drop = {size_before_drop} \nsize after drop = {size_after_drop}\nwhich is{100*((size_before_drop-size_after_drop)/size_before_drop)}')
# Out:
# size before drop = 246847
# size after drop = 4
# which is99.99837956304918

# %%
w_restaurant_df.isnull()
# Out:
#            id   name  domain_id  ...  hotel_restaurant  pet_friendly  delivery
# 0       False  False      False  ...              True          True      True
# 1       False  False      False  ...              True          True      True
# 2       False  False      False  ...              True          True      True
# 3       False  False      False  ...              True          True      True
# 4       False  False      False  ...              True          True      True
# ...       ...    ...        ...  ...               ...           ...       ...
# 246842  False  False      False  ...              True          True      True
# 246843  False  False      False  ...              True          True      True
# 246844  False  False      False  ...              True          True      True
# 246845  False  False      False  ...              True          True      True
# 246846  False  False      False  ...              True          True      True
#
# ...

# %%
w_restaurant_df.isnull().any()
# Out:
# id                         False
# name                       False
# domain_id                  False
# closed                     False
# city_name                  False
# zipcode                     True
# geohash                    False
# new_open                   False
# weighted_average_rating    False
# number_of_chains            True
# number_of_bookmarks         True
# number_of_reviews          False
# number_of_product_tags     False
# total_number_of_views      False
# number_of_checkins         False
# number_of_menu_groups      False
# number_of_menu_photos      False
# category_name              False
# price_range                 True
# avg_price                   True
# parking                     True
# credit_card_accepted        True
# good_for_groups             True
# good_for_kids               True
# bookable                    True
# best_of_wongnai             True
# wifi                        True
# number_of_seats             True
# ...

# %%
w_restaurant_df.dropna(subset=['id','name','price_range']).shape #เลือก drop เฉพาะคอลัมที่ต้องการ โดยใช้ subset
# Out:
# (180972, 32)

# %% [markdown]
# ## Method 2 (raplace with reasonable value)
#
# ค่าที่มาแทนที่

# %% [markdown]
# Methot 2 (raplace with reasonable value) แทนที่ด้วยค่าที่เหมาะสม
# เราจะไม่ให้ data หายไปเลย โดยการเอาค่า default ใส่เข้าไป คือ ค่ามาตรฐานของแต่ละฟิวส์¶
# เราจะใส่ค่า missing value เข้าไป

# %%
w_restaurant_df[['number_of_chains']] = w_restaurant_df[['number_of_chains']].fillna(0) 
#เราจะสร้างคอลัมใหม่ไปแทน number_of_chains โดยให้ค่าเป็นค่าเดิม แต่ missing จะถูกแทนด้วย 0 โดยใช้ __.fillna__

# %%
w_restaurant_df.isnull().any()
# Out:
# id                         False
# name                       False
# domain_id                  False
# closed                     False
# city_name                  False
# zipcode                     True
# geohash                    False
# new_open                   False
# weighted_average_rating    False
# number_of_chains           False
# number_of_bookmarks         True
# number_of_reviews          False
# number_of_product_tags     False
# total_number_of_views      False
# number_of_checkins         False
# number_of_menu_groups      False
# number_of_menu_photos      False
# category_name              False
# price_range                 True
# avg_price                   True
# parking                     True
# credit_card_accepted        True
# good_for_groups             True
# good_for_kids               True
# bookable                    True
# best_of_wongnai             True
# wifi                        True
# number_of_seats             True
# ...

# %% [markdown]
# โดยตัวเลขที่ใส่ใน fillna() จะเป็นค่าของส่วนใหญ่เช่น number_of_chains  ใส่ 0 เพราะร้านอาหารส่วนใหญ่ไม่มีสาขาย่อย หรือ การใช้อายุนศ. เป็น 18 เพราะ ปี1 ที่อายุ18 มีมากกว่าอายุอื่นๆ

# %% [markdown]
# ### Method 2 (raplace with unknow value)

# %%
w_restaurant_df[['number_of_chains']] = w_restaurant_df[['number_of_chains']].fillna(0)

# %%
w_restaurant_df.isnull().any()
# Out:
# id                         False
# name                       False
# domain_id                  False
# closed                     False
# city_name                  False
# zipcode                     True
# geohash                    False
# new_open                   False
# weighted_average_rating    False
# number_of_chains           False
# number_of_bookmarks         True
# number_of_reviews          False
# number_of_product_tags     False
# total_number_of_views      False
# number_of_checkins         False
# number_of_menu_groups      False
# number_of_menu_photos      False
# category_name              False
# price_range                 True
# avg_price                   True
# parking                     True
# credit_card_accepted        True
# good_for_groups             True
# good_for_kids               True
# bookable                    True
# best_of_wongnai             True
# wifi                        True
# number_of_seats             True
# ...

# %% [markdown]
# เติมค่าตามฟิวส์อื่น โดยพิจารณาคอลัมว่าแบ่งเป็นหน่วยย่อยๆได้

# %%
new_table = w_restaurant_df[['name','city_name','avg_price']]
new_table
# Out:
#                                         name  ... avg_price
# 0                           นครินทร์ทันตกรรม  ...       NaN
# 1                               Corner House  ...       NaN
# 2                             วัดโลกยสุธาราม  ...       NaN
# 3                             นันท์คาราโอเกะ  ...       NaN
# 4                                Buono Caffe  ...       NaN
# ...                                      ...  ...       ...
# 246842                            Sushi Tama  ...       NaN
# 246843                     สะบายดี คาราโอเกะ  ...       NaN
# 246844                      สเต็กแม่&กาแฟลูก  ...       NaN
# 246845                              Mom Made  ...       NaN
# 246846  ก๋วยเตี๋ยวหมูน้ำตก ก๋วยเตี๋ยวเรือทอง  ...       NaN
#
# [246847 rows x 3 columns]

# %% [markdown]
# PD select data วิธีเลือกข้อมูลใน padas โดยสามารเลือกตาม row ได้

# %%
new_table['city_name']=='Bangkok Metropolitan Region'
#เราจะเลือกให้ฟิวส์ city name โดยสร้างลิตส์ที่บอกว่าจะเอาข้อมูลอะไรบ้าง โดยจะสร้างลิตส์ที่มีจำนวนข้อมูลทั้งหมดก่อน
# Out:
# 0         False
# 1          True
# 2         False
# 3          True
# 4          True
#           ...
# 246842     True
# 246843     True
# 246844     True
# 246845    False
# 246846    False
# Name: city_name, Length: 246847, dtype: bool

# %%
new_table[new_table['city_name']=='Bangkok Metropolitan Region']
#จากนั้นในลิตส์ city_name จะเลือกข้อมูลที่มีแต่ Bangkok Metropolitan Region มาแสดงตามที่เราต้องการ
# Out:
#                      name                    city_name  avg_price
# 1            Corner House  Bangkok Metropolitan Region        NaN
# 3          นันท์คาราโอเกะ  Bangkok Metropolitan Region        NaN
# 4             Buono Caffe  Bangkok Metropolitan Region        NaN
# 7                Sazanami  Bangkok Metropolitan Region        NaN
# 10         Rotee Me Chabu  Bangkok Metropolitan Region        NaN
# ...                   ...                          ...        ...
# 246835     ร้านครัวแกงป่า  Bangkok Metropolitan Region        NaN
# 246840       โตข้าวต้มปลา  Bangkok Metropolitan Region        NaN
# 246842         Sushi Tama  Bangkok Metropolitan Region        NaN
# 246843  สะบายดี คาราโอเกะ  Bangkok Metropolitan Region        NaN
# 246844   สเต็กแม่&กาแฟลูก  Bangkok Metropolitan Region        NaN
#
# [100588 rows x 3 columns]

# %%
selected_list = new_table['city_name']=='Bangkok Metropolitan Region'
selected_list
# Out:
# 0         False
# 1          True
# 2         False
# 3          True
# 4          True
#           ...
# 246842     True
# 246843     True
# 246844     True
# 246845    False
# 246846    False
# Name: city_name, Length: 246847, dtype: bool

# %%
new_table[selected_list].head()
# Out:
#               name                    city_name  avg_price
# 1     Corner House  Bangkok Metropolitan Region        NaN
# 3   นันท์คาราโอเกะ  Bangkok Metropolitan Region        NaN
# 4      Buono Caffe  Bangkok Metropolitan Region        NaN
# 7         Sazanami  Bangkok Metropolitan Region        NaN
# 10  Rotee Me Chabu  Bangkok Metropolitan Region        NaN

# %% [markdown]
# #หาค่าเฉลี่ยของร้านในจังหวัดกรุงเทพ

# %%
#สร้างตารางขึ้นมาใหม่new_table แล้วเลือกตารางที่ city_name == Bangkok Metropolitan Region จากนั้นจึง .dropna() ค่าที่เป็น missing ออก
new_table[new_table['city_name']=='Bangkok Metropolitan Region'].dropna()['avg_price']
# Out:
# 67         375.0
# 134        175.0
# 247       1500.0
# 319        375.0
# 382        175.0
#            ...
# 246458      50.0
# 246472    1500.0
# 246508     375.0
# 246666     375.0
# 246721     375.0
# Name: avg_price, Length: 3001, dtype: float64

# %%
new_table[new_table['city_name']=='Bangkok Metropolitan Region'].dropna()['avg_price'].mean()
# หลังจากเอาค่า missing ออก จะหาค่าเฉลี่ยของคอลัม avg_price โดยใช้คำสั่ง .mean() เพื่อหาค่าเฉลี่ย
# Out:
# 392.5854715094968

# %% [markdown]
# 1.เลือกเฉพาะ กทม.

# %%
bkk_table = new_table[new_table['city_name']=='Bangkok Metropolitan Region']
bkk_table.head()
# Out:
#               name                    city_name  avg_price
# 1     Corner House  Bangkok Metropolitan Region        NaN
# 3   นันท์คาราโอเกะ  Bangkok Metropolitan Region        NaN
# 4      Buono Caffe  Bangkok Metropolitan Region        NaN
# 7         Sazanami  Bangkok Metropolitan Region        NaN
# 10  Rotee Me Chabu  Bangkok Metropolitan Region        NaN

# %% [markdown]
# 2.ลบค่า missing ออกไป

# %%
bkk_table_dp = bkk_table.dropna()
bkk_table_dp.head()
# Out:
#                             name                    city_name  avg_price
# 67                   เล็กกุ้งเผา  Bangkok Metropolitan Region      375.0
# 134                     Cafe Cha  Bangkok Metropolitan Region      175.0
# 247           Masterpiece clinic  Bangkok Metropolitan Region     1500.0
# 319  Chaba Nails & Eyelashes Pro  Bangkok Metropolitan Region      375.0
# 382                Panlee Bakery  Bangkok Metropolitan Region      175.0

# %% [markdown]
# 3.เลือกเฉพาะคอลัม avg_price

# %%
bkk_table_dp_avg_price = bkk_table_dp['avg_price']
bkk_table_dp_avg_price
# Out:
# 67         375.0
# 134        175.0
# 247       1500.0
# 319        375.0
# 382        175.0
#            ...
# 246458      50.0
# 246472    1500.0
# 246508     375.0
# 246666     375.0
# 246721     375.0
# Name: avg_price, Length: 3001, dtype: float64

# %% [markdown]
# 4.หาค่าเฉลี่ย

# %%
bkk_table_dp_avg_price.mean()
# Out:
# 392.5854715094968

# %% [markdown]
# #แก้ missing method 3 เติมค่าที่เหมาะสมตามกลุ่มของมัน

# %%
bkk_table[['avg_price']] = bkk_table[['avg_price']].fillna(bkk_table_dp_avg_price.mean())
bkk_table.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
#               name                    city_name   avg_price
# 1     Corner House  Bangkok Metropolitan Region  392.585472
# 3   นันท์คาราโอเกะ  Bangkok Metropolitan Region  392.585472
# 4      Buono Caffe  Bangkok Metropolitan Region  392.585472
# 7         Sazanami  Bangkok Metropolitan Region  392.585472
# 10  Rotee Me Chabu  Bangkok Metropolitan Region  392.585472

# %% [markdown]
# #Ex9 หาค่าเฉลี่ยของร้านในจังหวัดเชียงใหม่

# %%
new_table[new_table['city_name']=='Chiang Mai'].dropna()['avg_price']
# Out:
# 196       175.0
# 1465      375.0
# 2978       50.0
# 4683      175.0
# 4918      175.0
#           ...
# 243517     50.0
# 244433    175.0
# 244841     50.0
# 244937     50.0
# 245954    375.0
# Name: avg_price, Length: 464, dtype: float64

# %%
new_table[new_table['city_name']=='Chiang Mai'].dropna()['avg_price'].mean()
# Out:
# 188.41594827586206

# %%
cm_table = new_table[new_table['city_name']=='Chiang Mai']
cm_table[['avg_price']] = cm_table[['avg_price']].fillna(new_table[new_table['city_name']=='Chiang Mai'].dropna()['avg_price'].mean())
cm_table.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
#                             name   city_name   avg_price
# 36                   Wrap Master  Chiang Mai  188.415948
# 40                         Sozen  Chiang Mai  188.415948
# 52           ไวท์ดราก้อน หมูกะทะ  Chiang Mai  188.415948
# 60  เต-ชา ก๋วยเตี๋ยวไข่ไดโนเสาร์  Chiang Mai  188.415948
# 79            ก๋วยเตี๋ยวเรือสะใจ  Chiang Mai  188.415948

# %%
pd_concat = pandas.concat([bkk_table,cm_table])
pd_concat
# Out:
#                            name                    city_name   avg_price
# 1                  Corner House  Bangkok Metropolitan Region  392.585472
# 3                นันท์คาราโอเกะ  Bangkok Metropolitan Region  392.585472
# 4                   Buono Caffe  Bangkok Metropolitan Region  392.585472
# 7                      Sazanami  Bangkok Metropolitan Region  392.585472
# 10               Rotee Me Chabu  Bangkok Metropolitan Region  392.585472
# ...                         ...                          ...         ...
# 246783            ส้มตำลำฮิมกอง                   Chiang Mai  188.415948
# 246803  ไก่ทอดปักษ์ใต้ นายหัวโต                   Chiang Mai  188.415948
# 246808        แคลิฟอร์เนียเวร็ป                   Chiang Mai  188.415948
# 246813   TOONGs COFFEE Roasters                   Chiang Mai  188.415948
# 246826                ลาบเขยยอง                   Chiang Mai  188.415948
#
# [116258 rows x 3 columns]

# %% [markdown]
# #Method 3 Looping (concat)
# วนลูป concat
#
# 1.ดึงจังหวัดที่มีอยู่ทั้งหมดในตารางออกมา

# %%
all_cities = set(new_table['city_name'])
len(all_cities) #set คือ ตัวแปลอะไรที่ซ้ำกันจะตัดออกทั้งหมด
# Out:
# 479

# %% [markdown]
# 2.คำนวณหาค่ามีนของคอลัม city_name เพื่อเก็บไว้เติมใส่เมืองที่เป็น missing ทุกร้าน

# %%
all_mean = new_table.dropna(subset=['avg_price'])['avg_price'].mean() #หาค่าเฉลี่ยทั้งหมดเพื่อเอาไปใส่ตัวที่ missing
all_mean
# Out:
# 327.44728783902013

# %% [markdown]
# 3.สร้าง list ของตารางของทุกๆจังหวัดที่แก้ missing แล้ว แล้วไปวนลูป สร้าง list ของตารางรางของทุกๆจังหวัด

# %%
all_cities_list=[]
for each_city in list(all_cities):
  temp_table=new_table[new_table['city_name']==each_city]
  temp_table[['avg_price']]=temp_table[['avg_price']].fillna(new_table[new_table['city_name']==each_city].dropna()['avg_price'].mean())
  all_cities_list.append(temp_table)
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %% [markdown]
# 4.สร้างตารางจาก list ของตาราง ด้วย pd.concat

# %%
all_no_missing = pandas.concat(all_cities_list)
all_no_missing # ที่ยังขึ้น NaN เพราะ มีบางจังหวัดที่ไม่มีค่าเฉลี่ย
# Out:
#                                      name    city_name   avg_price
# 98149                  Chiayi Family Mart  Chiayi City         NaN
# 101546                               綠奶檸檬  Chiayi City         NaN
# 142631             郭家雞肉飯 Guo Chicken Rice  Chiayi City         NaN
# 150639    Chiayi Wenhua Road Night Market  Chiayi City         NaN
# 156297                              源興御香屋  Chiayi City         NaN
# ...                                   ...          ...         ...
# 245657                  Mean's Clean food     Thailand  185.714286
# 246017  บ้านพิซซ่า | Bann Pizza by Latina     Thailand  185.714286
# 246459                      ขนมครกชาวบ้าน     Thailand  185.714286
# 246503     We Grill You Chill Steak House     Thailand  185.714286
# 125676                  Good View Seafood        Sabah         NaN
#
# [246847 rows x 3 columns]

# %% [markdown]
# 5.เติมค่ามีนของทั้งตารางให้กับจังหวัดที่ไม่มีมีน

# %%
all_no_missing = all_no_missing.fillna(all_mean) # เติมค่าเฉลี่ยลงในจังหวัดที่ไม่มีค่าเฉลี่ย ด้วยค่าเฉลี่ยของทุกจังหวัด all_mean
all_no_missing.isnull().any() # เช็คว่ายังมี missing อยู่มั้ย
# Out:
# name         False
# city_name    False
# avg_price    False
# dtype: bool

# %%
all_no_missing
# Out:
#                                      name    city_name   avg_price
# 98149                  Chiayi Family Mart  Chiayi City  327.447288
# 101546                               綠奶檸檬  Chiayi City  327.447288
# 142631             郭家雞肉飯 Guo Chicken Rice  Chiayi City  327.447288
# 150639    Chiayi Wenhua Road Night Market  Chiayi City  327.447288
# 156297                              源興御香屋  Chiayi City  327.447288
# ...                                   ...          ...         ...
# 245657                  Mean's Clean food     Thailand  185.714286
# 246017  บ้านพิซซ่า | Bann Pizza by Latina     Thailand  185.714286
# 246459                      ขนมครกชาวบ้าน     Thailand  185.714286
# 246503     We Grill You Chill Steak House     Thailand  185.714286
# 125676                  Good View Seafood        Sabah  327.447288
#
# [246847 rows x 3 columns]

# %%
###Quiz วาด boxplot ของค่า 'price' ของตาราง all_no_missing (แนวนอน)

# %%
###Quiz วาด boxplot ของค่า 'price' ของตาราง all_no_missing (แนวนอน)

# %%
from matplotlib import pyplot as plt

# %%
plt.boxplot(all_no_missing['avg_price'],vert = False)
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f1ca3e9f320>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f1ca3e9fcf8>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7f1ca3e8f7b8>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7f1ca3e8f438>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f1ca53afe10>,
#   <matplotlib.lines.Line2D at 0x7f1ca3e9f978>]}

# %%
from matplotlib import pyplot as plt

# %%
ret=plt.boxplot(all_no_missing['avg_price'],vert=False)

# %%
ret #เป็น Dict
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f1ca397f1d0>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f1ca397fbe0>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7f1ca39876a0>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7f1ca3987320>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f1ca397f4e0>,
#   <matplotlib.lines.Line2D at 0x7f1ca397f860>]}

# %%
print(ret['whiskers'][0].get_xdata()) #whiskers ด้านซ้าย มี 2 เลข ตัวที่จะใช้คือ 138.157
print(ret['whiskers'][1].get_xdata()) #whiskers ด้านขวา[1] คือ 549 อยู่ลำดับ[1]
# Out:
# [283.54761905 138.15789474]
# [392.58547151 549.        ]

# %%
print(ret['whiskers'][0].get_xdata()[1])
print(ret['whiskers'][1].get_xdata()[1]) # แสดงค่าที่เราจะใช้
# Out:
# 138.1578947368421
# 549.0

# %%
#ทำการกำจัด outlier 
nooutlier_nomissing = all_no_missing[all_no_missing['avg_price']>=ret['whiskers'][0].get_xdata()[1]] #ตัด outlier แค่ด้านซ้าย
nooutlier_nomissing = nooutlier_nomissing[nooutlier_nomissing['avg_price']<=ret['whiskers'][1].get_xdata()[1]] #เอมาตัด Outlier ที่เหลือออก
nooutlier_nomissing
# Out:
#                                      name    city_name   avg_price
# 98149                  Chiayi Family Mart  Chiayi City  327.447288
# 101546                               綠奶檸檬  Chiayi City  327.447288
# 142631             郭家雞肉飯 Guo Chicken Rice  Chiayi City  327.447288
# 150639    Chiayi Wenhua Road Night Market  Chiayi City  327.447288
# 156297                              源興御香屋  Chiayi City  327.447288
# ...                                   ...          ...         ...
# 245657                  Mean's Clean food     Thailand  185.714286
# 246017  บ้านพิซซ่า | Bann Pizza by Latina     Thailand  185.714286
# 246459                      ขนมครกชาวบ้าน     Thailand  185.714286
# 246503     We Grill You Chill Steak House     Thailand  185.714286
# 125676                  Good View Seafood        Sabah  327.447288
#
# [243843 rows x 3 columns]

# %% [markdown]
# ##12/10/2020
# copy a colum from other table (.map())

# %% [markdown]
# #Data Integration
# การรวม 2 ตารางเข้าด้วยกัน
# merge two tables (.merge())
# มีตารางสองอันแล้วต้องการนำข้อมูลมาเชื่อมต่อรวมกันโดยอาศัยคอลัมน์หนึ่งเป็นตัวเชื่อมจะใช้ฟังก์ชัน .merge นั่นคือการเชื่อมโดยผ่านความสัมพันธ์ของค่าภายในตาราง

# %%
merged_table = search_click_df.merge(w_restaurant_df,how='left',left_on='business_id',right_on='id')
merged_table
# Out:
#         click_timestamp  ... delivery
# 0               11:38.9  ...      1.0
# 1               30:51.3  ...      1.0
# 2               32:09.6  ...      NaN
# 3               00:59.8  ...      1.0
# 4               23:36.8  ...      1.0
# ...                 ...  ...      ...
# 1048570         05:28.8  ...      NaN
# 1048571         15:28.8  ...      NaN
# 1048572         11:49.4  ...      1.0
# 1048573         10:33.7  ...      1.0
# 1048574         13:51.4  ...      NaN
#
# [1048575 rows x 38 columns]

# %% [markdown]
# copy a column from other table (.map())
# การไปดึงคอลัมอีกตารางมา

# %%
search_click_df['bu_name']=search_click_df['business_id'].map(w_restaurant_df.set_index('id')['city_name'])
search_click_df
# Out:
#         click_timestamp  ...                      bu_name
# 0               11:38.9  ...  Bangkok Metropolitan Region
# 1               30:51.3  ...  Bangkok Metropolitan Region
# 2               32:09.6  ...  Bangkok Metropolitan Region
# 3               00:59.8  ...  Bangkok Metropolitan Region
# 4               23:36.8  ...  Bangkok Metropolitan Region
# ...                 ...  ...                          ...
# 1048570         05:28.8  ...                   Chaiyaphum
# 1048571         15:28.8  ...  Bangkok Metropolitan Region
# 1048572         11:49.4  ...  Bangkok Metropolitan Region
# 1048573         10:33.7  ...  Bangkok Metropolitan Region
# 1048574         13:51.4  ...                 Prachin Buri
#
# [1048575 rows x 7 columns]

# %%
search_click_df['city'] = search_click_df['business_id'].map(w_restaurant_df.set_index('id')['city_name'])
search_click_df
# Out:
#         click_timestamp  ...                         city
# 0               11:38.9  ...  Bangkok Metropolitan Region
# 1               30:51.3  ...  Bangkok Metropolitan Region
# 2               32:09.6  ...  Bangkok Metropolitan Region
# 3               00:59.8  ...  Bangkok Metropolitan Region
# 4               23:36.8  ...  Bangkok Metropolitan Region
# ...                 ...  ...                          ...
# 1048570         05:28.8  ...                   Chaiyaphum
# 1048571         15:28.8  ...  Bangkok Metropolitan Region
# 1048572         11:49.4  ...  Bangkok Metropolitan Region
# 1048573         10:33.7  ...  Bangkok Metropolitan Region
# 1048574         13:51.4  ...                 Prachin Buri
#
# [1048575 rows x 8 columns]

# %%
search_click_df.groupby('business_id').count() #ร้านเดียวกันจับกรุ๊ปเดียวกัน
# Out:
#              click_timestamp  search_id  ...  ads  bu_name
# business_id                              ...
# 2.0                        4          4  ...    4        4
# 5.0                        2          2  ...    2        2
# 6.0                        6          6  ...    6        6
# 7.0                        3          3  ...    3        3
# 14.0                       5          5  ...    5        5
# ...                      ...        ...  ...  ...      ...
# 340060.0                   4          4  ...    4        4
# 340063.0                   1          1  ...    1        1
# 340067.0                   2          2  ...    2        2
# 340068.0                   6          6  ...    6        6
# 340070.0                   9          9  ...    9        9
#
# [141536 rows x 6 columns]

# %%
search_click_df.groupby('business_id').count().sort_values('click_timestamp')
#จากตาราง search_click เราจะ group เพื่อดูว่า แต่ละ id นั้นมีคนกดเข้าไปดูกี่ครั้ง โดยมีการเรียงลำดับด้วย .sort_values
# Out:
#              click_timestamp  search_id  display_position  ...   ads  bu_name  city
# business_id                                                ...
# 122473.0                   1          1                 1  ...     1        1     1
# 136485.0                   1          1                 1  ...     1        1     1
# 275120.0                   1          1                 1  ...     1        1     1
# 136492.0                   1          1                 1  ...     1        1     1
# 136498.0                   1          1                 1  ...     1        1     1
# ...                      ...        ...               ...  ...   ...      ...   ...
# 150227.0                1377       1377              1377  ...  1377     1377  1377
# 273486.0                1417       1417              1417  ...  1417     1417  1417
# 112509.0                2130       2130              2130  ...  2130     2130  2130
# ...

# %%
w_restaurant_df[w_restaurant_df['id']==182530]
# Out:
#             id      name  domain_id  ...  hotel_restaurant pet_friendly delivery
# 124030  182530  หนานหยวน          1  ...               NaN          NaN      NaN
#
# [1 rows x 32 columns]

# %% [markdown]
# Quiz หาจังหวัดที่มีคน click เข้าไปมากที่สุดสามอันดับแรก

# %%
search_click_df['city'] = search_click_df['business_id'].map(w_restaurant_df.set_index('id')['city_name'])
search_click_df
# Out:
#         click_timestamp  ...                         city
# 0               11:38.9  ...  Bangkok Metropolitan Region
# 1               30:51.3  ...  Bangkok Metropolitan Region
# 2               32:09.6  ...  Bangkok Metropolitan Region
# 3               00:59.8  ...  Bangkok Metropolitan Region
# 4               23:36.8  ...  Bangkok Metropolitan Region
# ...                 ...  ...                          ...
# 1048570         05:28.8  ...                   Chaiyaphum
# 1048571         15:28.8  ...  Bangkok Metropolitan Region
# 1048572         11:49.4  ...  Bangkok Metropolitan Region
# 1048573         10:33.7  ...  Bangkok Metropolitan Region
# 1048574         13:51.4  ...                 Prachin Buri
#
# [1048575 rows x 8 columns]

# %%
search_click_df.groupby('city').count().sort_values('click_timestamp')
# Out:
#                              click_timestamp  search_id  ...     ads  bu_name
# city                                                     ...
# Wisconsin                                  1          1  ...       1        1
# Mie-ken                                    1          1  ...       1        1
# Tamil Nadu                                 1          1  ...       1        1
# Vladimirskaya oblast'                      1          1  ...       1        1
# Tainan City                                1          1  ...       1        1
# ...                                      ...        ...  ...     ...      ...
# Rayong                                 17986      17986  ...   17986    17986
# Phuket                                 18560      18560  ...   18560    18560
# Chon Buri                              51535      51535  ...   51535    51535
# Chiang Mai                             56775      56775  ...   56775    56775
# ...

# %%
search_click_df.groupby('city').count().sort_values('click_timestamp').iloc[-3:,:]
# Out:
#                              click_timestamp  search_id  ...     ads  bu_name
# city                                                     ...
# Chon Buri                              51535      51535  ...   51535    51535
# Chiang Mai                             56775      56775  ...   56775    56775
# Bangkok Metropolitan Region           596980     596963  ...  596980   596980
#
# [3 rows x 7 columns]

# %% [markdown]
# #เฉลยยย

# %%
search_click_df.groupby('city').count().sort_values('click_timestamp').iloc[-3:,:] 
#หน้าคอมมาบอกว่าเอา row ไหนบ้าง ตัวข้างหลังจะเอาคอลัมไหนบ้าง ใส่ : เพื่อบอกว่าจบลงที่ไหน เริ่มต้นที่ไหน
#iloc เริ่มต้นเอาตั้งแต่ row ที่ -3 ไปจนถึงคอลัมสุดท้าย 
#เปลี่ยนเป็นตาราง arry โดยใช้ iloc มาตัดตารางเอา 3 อันดับสุดท้าย
# Out:
#                              click_timestamp  search_id  ...     ads  bu_name
# city                                                     ...
# Chon Buri                              51535      51535  ...   51535    51535
# Chiang Mai                             56775      56775  ...   56775    56775
# Bangkok Metropolitan Region           596980     596963  ...  596980   596980
#
# [3 rows x 7 columns]

# %%
search_click_df.groupby('city').count().sort_values('click_timestamp',ascending=False).iloc[:3:,:]
#เรียงจากมากไปน้อยโดยเอาแค่ 3 ตัวบน
#โดยจะเอาตั้งแต่ตัวแรกไปจนถึงตัวที่ 3
# Out:
#                              click_timestamp  search_id  ...     ads  bu_name
# city                                                     ...
# Bangkok Metropolitan Region           596980     596963  ...  596980   596980
# Chiang Mai                             56775      56775  ...   56775    56775
# Chon Buri                              51535      51535  ...   51535    51535
#
# [3 rows x 7 columns]

# %% [markdown]
# ##QUIZเมืองไหนที่มีค่าเฉลี่ยของ 'weighted_average_rating' สูงที่สุด

# %%
w_restaurant_df.groupby('city_name').mean()
# Out:
#                                       id  domain_id  ...  pet_friendly  delivery
# city_name                                            ...
# Abu Dhabi                  180200.000000   1.000000  ...           NaN       NaN
# Aichi-ken                  181557.633803   1.000000  ...           NaN       NaN
# Akershus                   196643.666667   1.000000  ...           NaN       NaN
# Akita-ken                   12908.000000   1.000000  ...           NaN       NaN
# Al Farwaniyah Governorate  166274.000000   1.000000  ...           NaN       NaN
# ...                                  ...        ...  ...           ...       ...
# Ōita-ken                   187412.791045   1.000000  ...           NaN       NaN
# Ōsaka-fu                   182106.134483   1.000000  ...           NaN       NaN
# محافظة المحرق               92784.000000   1.000000  ...           NaN       NaN
# สงขลา                      180144.823398   1.070950  ...       0.10084  0.616822
# ...

# %%
w_restaurant_df.groupby('city_name').mean().sort_values('weighted_average_rating',ascending=False)
# Out:
#                                       id  domain_id  ...  pet_friendly  delivery
# city_name                                            ...
# Khartoum                   303589.000000        1.0  ...           NaN       NaN
# Cairo Governorate          277711.000000        1.0  ...           NaN       NaN
# Vaud                       161710.500000        1.0  ...           NaN       NaN
# Borno                      276020.000000        2.0  ...           NaN       NaN
# Kepulauan Riau             145430.500000        1.0  ...           NaN       NaN
# ...                                  ...        ...  ...           ...       ...
# Castilla-La Mancha         210336.333333        1.0  ...           NaN       NaN
# Capital Region of Denmark  134835.000000        1.0  ...           NaN       NaN
# Région de Kidal            240208.500000        2.0  ...           NaN       NaN
# Region Zealand             115070.000000        1.0  ...           NaN       NaN
# ...

# %% [markdown]
# ##EX เมืองไหนมีค่าเฉลี่ยของ weighted_average_rating สูงที่สุด แบบน่าเชื่อถือที่สุด number_of_reviews สูงที่สุด

# %%
sorted_star = w_restaurant_df.groupby('city_name').mean().sort_values('weighted_average_rating',ascending=False)
sorted_star
# Out:
#                                       id  domain_id  ...  pet_friendly  delivery
# city_name                                            ...
# Khartoum                   303589.000000        1.0  ...           NaN       NaN
# Cairo Governorate          277711.000000        1.0  ...           NaN       NaN
# Vaud                       161710.500000        1.0  ...           NaN       NaN
# Borno                      276020.000000        2.0  ...           NaN       NaN
# Kepulauan Riau             145430.500000        1.0  ...           NaN       NaN
# ...                                  ...        ...  ...           ...       ...
# Castilla-La Mancha         210336.333333        1.0  ...           NaN       NaN
# Capital Region of Denmark  134835.000000        1.0  ...           NaN       NaN
# Région de Kidal            240208.500000        2.0  ...           NaN       NaN
# Region Zealand             115070.000000        1.0  ...           NaN       NaN
# ...

# %%
sorted_star[sorted_star['number_of_reviews']>=5]
#สร้างตัวแปร sorted_star มารับค่าจากการดูค่าเฉลี่ยแล้ว อยากรู้คนรีวิวสร้างตัวแปรมาวนลูปว่าถ้าคนรีวิว >= 5 ให้แสดงออกมา
# Out:
#                                         id  domain_id  ...  pet_friendly  delivery
# city_name                                              ...
# Maldives                     242953.000000   1.000000  ...           NaN       NaN
# Chiang Mai                   179078.979643   1.168028  ...      0.067387  0.164958
# Bangkok Metropolitan Region  179658.982155   1.117261  ...      0.162970  0.915868
# Hua Hin                      180926.866138   1.167576  ...      0.144144  0.409091
#
# [4 rows x 27 columns]

# %% [markdown]
# SAVE to use with other applications

# %%
search_click_df.to_csv('search_click_extracted_time.csv')
#คำสั่งใช้เซฟตาราง
